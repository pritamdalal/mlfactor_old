# %%
import numpy as np
import pandas as pd

# %%
df_ml = pd.read_csv("../data/data_ml.csv")

# %%
separation_date = "2013-12-31"
df_train = df_ml.query("date < @separation_date").copy()
df_test = df_ml.query("@separation_date <= date & date < '2018-12-31'").copy()

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
columns_to_drop = [
    "stock_id", "date", # non-feature identifiers
    "R1M_Usd", "R3M_Usd", "R6M_Usd", "R12M_Usd", # numerical labels
    "R1M_Usd_C", "R12M_Usd_C" # categorical labels
]

features = list(df_ml.drop(columns=columns_to_drop).columns)

# %%
X_train = df_train[features]
y_train = df_train["R1M_Usd_C"]

# %%
X_test = df_test[features]
y_test = df_test["R1M_Usd_C"]

# %%
model = RandomForestClassifier(max_depth=5, random_state=0, n_jobs=-1)

# %%
model.fit(X_train, y_train)
# Out:
# RandomForestClassifier(max_depth=5, n_jobs=-1, random_state=0)

# %%
model.score(X_train, y_train)
# Out:
# 0.5316985706348806

# %%
df_test["prediction_hard"] = model.predict(X_test)
df_test["predict_prob_0"] = model.predict_proba(X_test)[:,0]
df_test["predict_prob_1"] = model.predict_proba(X_test)[:,1]

# %%
df_screen = df_test[["date", "R1M_Usd", "prediction_hard", "predict_prob_0", "predict_prob_1"]]
df_screen
# Out:
#               date  R1M_Usd  prediction_hard  predict_prob_0  predict_prob_1
# 3       2015-03-31    0.174              1.0        0.499717        0.500283
# 4       2015-04-30   -0.106              1.0        0.493392        0.506608
# 5       2015-05-31   -0.185              1.0        0.497036        0.502964
# 6       2015-06-30   -0.418              1.0        0.491069        0.508931
# 7       2015-07-31    0.575              1.0        0.485765        0.514235
# ...            ...      ...              ...             ...             ...
# 269373  2018-07-31    0.028              0.0        0.547788        0.452212
# 269374  2018-08-31   -0.101              0.0        0.547826        0.452174
# 269375  2018-09-30    0.013              0.0        0.548498        0.451502
# 269376  2018-10-31    0.039              0.0        0.541317        0.458683
# 269377  2018-11-30   -0.151              0.0        0.548925        0.451075
#
# [70489 rows x 5 columns]

# %%
df_monthly_returns = df_screen.query("prediction_hard == 1").groupby("date")[["R1M_Usd"]].mean().reset_index()
df_monthly_returns['growth_factor'] = 1 + df_monthly_returns['R1M_Usd']
df_monthly_returns['equity_curve'] = df_monthly_returns['growth_factor'].cumprod()
df_monthly_returns
# Out:
#           date   R1M_Usd  growth_factor  equity_curve
# 0   2013-12-31 -0.032255       0.967745      0.967745
# 1   2014-01-31  0.040904       1.040904      1.007329
# 2   2014-02-28  0.010195       1.010195      1.017599
# 3   2014-03-31  0.000505       1.000505      1.018112
# 4   2014-04-30  0.014474       1.014474      1.032849
# 5   2014-05-31  0.037330       1.037330      1.071405
# 6   2014-06-30 -0.050275       0.949725      1.017541
# 7   2014-07-31  0.046506       1.046506      1.064863
# 8   2014-08-31 -0.056308       0.943692      1.004903
# 9   2014-09-30  0.072662       1.072662      1.077921
# 10  2014-10-31  0.022346       1.022346      1.102007
# 11  2014-11-30  0.026093       1.026093      1.130762
# 12  2014-12-31 -0.034663       0.965337      1.091567
# 13  2015-01-31  0.053488       1.053488      1.149953
# 14  2015-02-28  0.005144       1.005144      1.155868
# 15  2015-03-31 -0.018435       0.981565      1.134559
# 16  2015-04-30  0.007620       1.007620      1.143205
# 17  2015-05-31 -0.008718       0.991282      1.133239
# 18  2015-06-30 -0.023571       0.976429      1.106528
# 19  2015-07-31 -0.042096       0.957904      1.059947
# 20  2015-08-31 -0.046614       0.953386      1.010539
# 21  2015-09-30  0.079302       1.079302      1.090677
# 22  2015-10-31  0.018537       1.018537      1.110895
# 23  2015-11-30 -0.045476       0.954524      1.060376
# 24  2015-12-31 -0.059374       0.940626      0.997417
# 25  2016-01-31  0.031814       1.031814      1.029148
# 26  2016-02-29  0.103217       1.103217      1.135374
# 27  2016-03-31  0.026183       1.026183      1.165102
# 28  2016-04-30  0.006705       1.006705      1.172914
# 29  2016-05-31  0.009808       1.009808      1.184418
# 30  2016-06-30  0.061668       1.061668      1.257458
# 31  2016-07-31  0.006783       1.006783      1.265988
# 32  2016-08-31 -0.003051       0.996949      1.262125
# 33  2016-09-30 -0.027315       0.972685      1.227650
# 34  2016-10-31  0.113048       1.113048      1.366433
# 35  2016-11-30  0.030350       1.030350      1.407905
# 36  2016-12-31  0.001369       1.001369      1.409832
# 37  2017-01-31  0.009519       1.009519      1.423252
# 38  2017-02-28  0.004036       1.004036      1.428997
# 39  2017-03-31  0.014227       1.014227      1.449327
# 40  2017-04-30 -0.023671       0.976329      1.415020
# 41  2017-05-31  0.025440       1.025440      1.451018
# 42  2017-06-30  0.026583       1.026583      1.489590
# 43  2017-07-31  0.024727       1.024727      1.526423
# 44  2017-08-31  0.074824       1.074824      1.640636
# 45  2017-09-30  0.002957       1.002957      1.645487
# 46  2017-10-31  0.045689       1.045689      1.720667
# 47  2017-11-30  0.000837       1.000837      1.722107
# 48  2017-12-31  0.015576       1.015576      1.748930
# 49  2018-01-31 -0.069649       0.930351      1.627120
# 50  2018-02-28  0.010244       1.010244      1.643788
# 51  2018-03-31  0.010756       1.010756      1.661469
# 52  2018-04-30  0.041329       1.041329      1.730136
# 53  2018-05-31  0.009234       1.009234      1.746112
# 54  2018-06-30  0.039508       1.039508      1.815097
# 55  2018-07-31  0.064753       1.064753      1.932631
# 56  2018-08-31 -0.011332       0.988668      1.910731
# 57  2018-09-30 -0.084075       0.915925      1.750086
# 58  2018-10-31  0.017295       1.017295      1.780354
# 59  2018-11-30 -0.112559       0.887441      1.579959

# %%
rebalance_dates = list(np.sort(df_screen["date"].unique()))
rebalance_dates
# Out:
# ['2013-12-31',
#  '2014-01-31',
#  '2014-02-28',
#  '2014-03-31',
#  '2014-04-30',
#  '2014-05-31',
#  '2014-06-30',
#  '2014-07-31',
#  '2014-08-31',
#  '2014-09-30',
#  '2014-10-31',
#  '2014-11-30',
#  '2014-12-31',
#  '2015-01-31',
#  '2015-02-28',
#  '2015-03-31',
#  '2015-04-30',
#  '2015-05-31',
#  '2015-06-30',
#  '2015-07-31',
#  '2015-08-31',
#  '2015-09-30',
#  '2015-10-31',
#  '2015-11-30',
#  '2015-12-31',
#  '2016-01-31',
#  '2016-02-29',
#  '2016-03-31',
#  '2016-04-30',
#  '2016-05-31',
#  '2016-06-30',
#  '2016-07-31',
#  '2016-08-31',
#  '2016-09-30',
#  '2016-10-31',
#  '2016-11-30',
#  '2016-12-31',
#  '2017-01-31',
#  '2017-02-28',
#  '2017-03-31',
#  '2017-04-30',
#  '2017-05-31',
#  '2017-06-30',
#  '2017-07-31',
#  '2017-08-31',
#  '2017-09-30',
#  '2017-10-31',
#  '2017-11-30',
#  '2017-12-31',
#  '2018-01-31',
#  '2018-02-28',
#  '2018-03-31',
#  '2018-04-30',
#  '2018-05-31',
#  '2018-06-30',
#  '2018-07-31',
#  '2018-08-31',
#  '2018-09-30',
#  '2018-10-31',
#  '2018-11-30']

# %%
lst_trades = []
for ix_date in rebalance_dates:
    df = df_screen.query("date == @ix_date").sort_values(by="predict_prob_1", ascending=False).head(200).copy()
    lst_trades.append(df)
df_trades = pd.concat(lst_trades)
df_trades
# Out:
#               date  R1M_Usd  prediction_hard  predict_prob_0  predict_prob_1
# 14897   2013-12-31   -0.143              1.0        0.470221        0.529779
# 13913   2013-12-31   -0.068              1.0        0.471442        0.528558
# 32761   2013-12-31   -0.022              1.0        0.472757        0.527243
# 56081   2013-12-31   -0.060              1.0        0.474221        0.525779
# 12870   2013-12-31   -0.077              1.0        0.475476        0.524524
# ...            ...      ...              ...             ...             ...
# 206807  2018-11-30   -0.087              1.0        0.490301        0.509699
# 66467   2018-11-30   -0.072              1.0        0.490318        0.509682
# 75220   2018-11-30    0.015              1.0        0.490341        0.509659
# 130664  2018-11-30   -0.093              1.0        0.490345        0.509655
# 145177  2018-11-30   -0.032              1.0        0.490350        0.509650
#
# [12000 rows x 5 columns]

# %%
df_monthly_returns = df_trades.groupby("date")[["R1M_Usd"]].mean().reset_index()
df_monthly_returns['growth_factor'] = 1 + df_monthly_returns['R1M_Usd']
df_monthly_returns['equity_curve'] = df_monthly_returns['growth_factor'].cumprod()
df_monthly_returns
# Out:
